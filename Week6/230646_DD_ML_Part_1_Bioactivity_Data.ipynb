# %% [markdown]
# #**Drug Discovery [Part 1] Download Bioactivity Data**

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 483.0 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 2.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for SARS Coronavirus 3C like protinase**

# %%
target = new_client.target
target_query = target.search('influenza')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P03438', 'xref_name': None, 'xre...
# 5                                                 []
# 6                                                 []
# 7  [{'xref_id': 'P63231', 'xref_name': None, 'xre...
# 8                                                 []
# 9                                                 []
#
#                                          organism  \
# 0                    unidentified influenza virus
# 1                               Influenza B virus
# 2                               Influenza A virus
# 3                               Influenza C virus
# 4          Influenza A virus (strain A/X-31 H3N2)
# 5                          Influenza A virus H3N2
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for SARS Coronavirus** (sixth entry)

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL2366902'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *SARS Coronavirus* (CHEMBL3927) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      2563883                  []
# 1          None             None      2563886                  []
# 2          None             None      2601699                  []
# 3          None             None      2601849                  []
# 4          None             None      2601877                  []
# ..          ...              ...          ...                 ...
# 126        None             None     19139127                  []
# 127        None             None     19171775                  []
# 128        None             None     19285279                  []
# 129        None             None     19285280                  []
# 130        None             None     20673572                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL979079  Antiviral activity against Influenza virus (A/...
# ...

# %%
df.to_csv('H3N1_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-33-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      2563883                  []
# 1          None             None      2563886                  []
# 2          None             None      2601699                  []
# 3          None             None      2601849                  []
# 4          None             None      2601877                  []
# ..          ...              ...          ...                 ...
# 126        None             None     19139127                  []
# 127        None             None     19171775                  []
# 128        None             None     19285279                  []
# 129        None             None     19285280                  []
# 130        None             None     20673572                  []
#
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 98

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      2563883                  []
# 2          None             None      2601699                  []
# 3          None             None      2601849                  []
# 4          None             None      2601877                  []
# 5          None             None      2602012                  []
# ..          ...              ...          ...                 ...
# 126        None             None     19139127                  []
# 127        None             None     19171775                  []
# 128        None             None     19285279                  []
# 129        None             None     19285280                  []
# 130        None             None     20673572                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL979079  Antiviral activity against Influenza virus (A/...
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL502613  CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)O[C@](OC...
# 2         CHEMBL222813  CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)OC(C(=O)...
# 3         CHEMBL455019         CCC(CC)C(NC(C)=O)C1C(NC(=N)N)CC(C(=O)O)C1O
# 4           CHEMBL1643   NC(=O)c1ncn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)n1
# 5            CHEMBL674   CCC(CC)O[C@@H]1C=C(C(=O)O)C[C@H](N)[C@H]1NC(C)=O
# ..                 ...                                                ...
# 126      CHEMBL4483331  C=C(C(=O)OC)[C@@H]1CC[C@H](C)[C@H]2C(=C(C)C(=O...
# 127      CHEMBL4554496  CC/C=C1/C=CC(=O)[C@@H](O)[C@]12C(=O)N(OC)[C@@]...
# 128      CHEMBL4578422  CC1(C)CC[C@]2(C(=O)N[C@@H](CCCNC(=N)N)C(=O)O)C...
# 129      CHEMBL1200340  CCOC(=O)C1=C[C@@H](OC(CC)CC)[C@H](NC(C)=O)[C@@...
# 130      CHEMBL4639026  CC(=O)c1cc(C)c(O)c(Cc2[nH]c3ccccc3c2Cc2c(O)c(C...
#
#     standard_value
# 0           3000.0
# 2            680.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('H3N1_02_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('H3N1_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL502613  CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)O[C@](OC...
# 1        CHEMBL222813  CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)OC(C(=O)...
# 2        CHEMBL455019         CCC(CC)C(NC(C)=O)C1C(NC(=N)N)CC(C(=O)O)C1O
# 3          CHEMBL1643   NC(=O)c1ncn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)n1
# 4           CHEMBL674   CCC(CC)O[C@@H]1C=C(C(=O)O)C[C@H](N)[C@H]1NC(C)=O
# ..                ...                                                ...
# 93      CHEMBL4483331  C=C(C(=O)OC)[C@@H]1CC[C@H](C)[C@H]2C(=C(C)C(=O...
# 94      CHEMBL4554496  CC/C=C1/C=CC(=O)[C@@H](O)[C@]12C(=O)N(OC)[C@@]...
# 95      CHEMBL4578422  CC1(C)CC[C@]2(C(=O)N[C@@H](CCCNC(=N)N)C(=O)O)C...
# 96      CHEMBL1200340  CCOC(=O)C1=C[C@@H](OC(CC)CC)[C@H](NC(C)=O)[C@@...
# 97      CHEMBL4639026  CC(=O)c1cc(C)c(O)c(Cc2[nH]c3ccccc3c2Cc2c(O)c(C...
#
#     standard_value         class
# 0           3000.0  intermediate
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('H3N1_03_bioactivity_data_curated.csv', index=False)

# %%
! zip H3N1.zip *.csv
# Out:
#   adding: coronavirus_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: coronavirus_02_bioactivity_data_preprocessed.csv (deflated 78%)
#   adding: H3N1_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: H3N1_02_bioactivity_data_preprocessed.csv (deflated 78%)
#   adding: H3N1_03_bioactivity_data_curated.csv (deflated 79%)

# %%
! ls -l
# Out:
# total 240
# -rw-r--r-- 1 root root 75933 Jul 11 07:35 coronavirus_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  9618 Jul 11 07:36 coronavirus_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 20969 Jul 11 07:38 coronavirus.zip
# -rw-r--r-- 1 root root 75933 Jul 11 07:36 H3N1_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  9618 Jul 11 07:37 H3N1_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 10436 Jul 11 07:37 H3N1_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 20969 Jul 11 07:38 H3N1.zip
# drwxr-xr-x 1 root root  4096 Jul  9 13:21 sample_data

# %% [markdown]
# ---
